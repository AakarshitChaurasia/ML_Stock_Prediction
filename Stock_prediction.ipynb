# %%
#Importing the Libraries
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib. pyplot as plt
import matplotlib
from sklearn import preprocessing
from sklearn.preprocessing import MinMaxScaler
from keras.layers import LSTM, Dense, Dropout
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib. dates as mandates
from sklearn.preprocessing import MinMaxScaler
from sklearn import linear_model

from keras.models import Sequential
from keras.layers import Dense
import keras.backend as K
from keras.callbacks import EarlyStopping
from keras.optimizers import adam_v2
from keras.models import load_model
from keras.layers import LSTM
from keras.utils.vis_utils import plot_model

# %%
#Get the Dataset
df=pd.read_csv('MSFT.csv',na_values=['null'],index_col='Date',parse_dates=True,infer_datetime_format=True)
df.head()
# Out:
#                 Open      High       Low     Close  Adj Close      Volume
# Date
# 1986-03-13  0.088542  0.101563  0.088542  0.097222   0.061434  1031788800
# 1986-03-14  0.097222  0.102431  0.097222  0.100694   0.063628   308160000
# 1986-03-17  0.100694  0.103299  0.100694  0.102431   0.064725   133171200
# 1986-03-18  0.102431  0.103299  0.098958  0.099826   0.063079    67766400
# 1986-03-19  0.099826  0.100694  0.097222  0.098090   0.061982    47894400

# %%
#Print the shape of Dataframe  and Check for Null Values
print('Dataframe Shape: ', df.shape)
print('Null Value Present: ', df.isnull().values.any())
# Out:
# Dataframe Shape:  (9083, 6)
# Null Value Present:  False

# %%
#Plot the True Adj Close Value
df['Adj Close'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
#Set Target Variable
output_var = pd.DataFrame(df['Adj Close'])
#Selecting the Features
features = ['Open', 'High', 'Low', 'Volume']

# %%
#Scaling
scaler = MinMaxScaler()
feature_transform = scaler.fit_transform(df[features])
feature_transform= pd.DataFrame(columns=features, data=feature_transform, index=df.index)
feature_transform.head()
# Out:
#                 Open      High       Low    Volume
# Date
# 1986-03-13  0.000000  0.000027  0.000000  1.000000
# 1986-03-14  0.000025  0.000030  0.000025  0.297096
# 1986-03-17  0.000035  0.000032  0.000036  0.127119
# 1986-03-18  0.000040  0.000032  0.000030  0.063588
# 1986-03-19  0.000033  0.000025  0.000025  0.044285

# %%
#Splitting to Training set and Test set
timesplit= TimeSeriesSplit(n_splits=10)
for train_index, test_index in timesplit.split(feature_transform):
        X_train, X_test = feature_transform[:len(train_index)], feature_transform[len(train_index): (len(train_index)+len(test_index))]
        y_train, y_test = output_var[:len(train_index)].values.ravel(), output_var[len(train_index): (len(train_index)+len(test_index))].values.ravel()

# %%
#Process the data for LSTM
trainX =np.array(X_train)
testX =np.array(X_test)
X_train = trainX.reshape(X_train.shape[0], 1, X_train.shape[1])
X_test = testX.reshape(X_test.shape[0], 1, X_test.shape[1])

# %%
import pydot
import graphviz
#You must install pydot (`pip install pydot`) and install graphviz
#(see instructions at https://graphviz.gitlab.io/download/) for plot_model/model_to_dot to work.

# %%
#Building the LSTM Model
lstm = Sequential()
lstm.add(LSTM(32, input_shape=(1, trainX.shape[1]), activation='relu', return_sequences=False))
lstm.add(Dense(1))
lstm.compile(loss='mean_squared_error', optimizer='adam')
plot_model(lstm, show_shapes=True, show_layer_names=True)

# %%
#Model Training
history=lstm.fit(X_train, y_train, epochs=100, batch_size=8, verbose=1, shuffle=False)
# Out:
# Epoch 1/100
# 1033/1033 [==============================] - 8s 3ms/step - loss: 245.6734
# Epoch 2/100
# 1033/1033 [==============================] - 3s 3ms/step - loss: 211.0509
# Epoch 3/100
# 1033/1033 [==============================] - 3s 3ms/step - loss: 217.6973
# Epoch 4/100
# 1033/1033 [==============================] - 3s 3ms/step - loss: 157.4012
# Epoch 5/100
# 1033/1033 [==============================] - 3s 3ms/step - loss: 100.9595
# Epoch 6/100
# 1033/1033 [==============================] - 3s 3ms/step - loss: 54.0887
# Epoch 7/100
# 1033/1033 [==============================] - 3s 3ms/step - loss: 23.8524
# Epoch 8/100
# 1033/1033 [==============================] - 3s 3ms/step - loss: 10.5680
# Epoch 9/100
# 1033/1033 [==============================] - 3s 3ms/step - loss: 6.3641
# Epoch 10/100
# 1033/1033 [==============================] - 3s 3ms/step - loss: 5.0838
# Epoch 11/100
# 1033/1033 [==============================] - 3s 3ms/step - loss: 4.4987
# Epoch 12/100
# 1033/1033 [==============================] - 3s 3ms/step - loss: 4.0107
# Epoch 13/100
# 1033/1033 [==============================] - 3s 3ms/step - loss: 3.5422
# Epoch 14/100
# 1033/1033 [==============================] - 4s 3ms/step - loss: 3.1364
# Epoch 15/100
# 1033/1033 [==============================] - 4s 3ms/step - loss: 2.8119
# Epoch 16/100
# 1033/1033 [==============================] - 3s 3ms/step - loss: 2.5606
# Epoch 17/100
# 1033/1033 [==============================] - 3s 3ms/step - loss: 2.3655
# Epoch 18/100
# 1033/1033 [==============================] - 3s 3ms/step - loss: 2.2105
# Epoch 19/100
# 1033/1033 [==============================] - 3s 3ms/step - loss: 2.0838
# Epoch 20/100
# 1033/1033 [==============================] - 3s 3ms/step - loss: 1.9780
# Epoch 21/100
# 1033/1033 [==============================] - 3s 3ms/step - loss: 1.8878
# Epoch 22/100
# 1033/1033 [==============================] - 3s 3ms/step - loss: 1.8101
# Epoch 23/100
# 1033/1033 [==============================] - 3s 3ms/step - loss: 1.7427
# Epoch 24/100
# 1033/1033 [==============================] - 3s 3ms/step - loss: 1.6836
# Epoch 25/100
# 1033/1033 [==============================] - 3s 3ms/step - loss: 1.6315
# Epoch 26/100
# 1033/1033 [==============================] - 3s 3ms/step - loss: 1.5853
# Epoch 27/100
# 1033/1033 [==============================] - 3s 3ms/step - loss: 1.5444
# Epoch 28/100
# 1033/1033 [==============================] - 3s 3ms/step - loss: 1.5076
# Epoch 29/100
# 1033/1033 [==============================] - 3s 3ms/step - loss: 1.4747
# Epoch 30/100
# 1033/1033 [==============================] - 3s 3ms/step - loss: 1.4450
# Epoch 31/100
# 1033/1033 [==============================] - 3s 3ms/step - loss: 1.4182
# Epoch 32/100
# 1033/1033 [==============================] - 3s 3ms/step - loss: 1.3938
# Epoch 33/100
# 1033/1033 [==============================] - 3s 3ms/step - loss: 1.3716
# Epoch 34/100
# 1033/1033 [==============================] - 3s 3ms/step - loss: 1.3513
# Epoch 35/100
# 1033/1033 [==============================] - 3s 3ms/step - loss: 1.3327
# Epoch 36/100
# 1033/1033 [==============================] - 3s 3ms/step - loss: 1.3157
# Epoch 37/100
# 1033/1033 [==============================] - 3s 3ms/step - loss: 1.2999
# Epoch 38/100
# 1033/1033 [==============================] - 3s 3ms/step - loss: 1.2854
# Epoch 39/100
# 1033/1033 [==============================] - 3s 3ms/step - loss: 1.2718
# Epoch 40/100
# 1033/1033 [==============================] - 3s 3ms/step - loss: 1.2593
# Epoch 41/100
# 1033/1033 [==============================] - 3s 3ms/step - loss: 1.2476
# Epoch 42/100
# 1033/1033 [==============================] - 3s 3ms/step - loss: 1.2367
# Epoch 43/100
# 1033/1033 [==============================] - 3s 3ms/step - loss: 1.2265
# Epoch 44/100
# 1033/1033 [==============================] - 3s 3ms/step - loss: 1.2168
# Epoch 45/100
# 1033/1033 [==============================] - 3s 3ms/step - loss: 1.2079
# Epoch 46/100
# 1033/1033 [==============================] - 3s 3ms/step - loss: 1.1994
# Epoch 47/100
# 1033/1033 [==============================] - 3s 3ms/step - loss: 1.1913
# Epoch 48/100
# 1033/1033 [==============================] - 3s 3ms/step - loss: 1.1837
# Epoch 49/100
# 1033/1033 [==============================] - 3s 3ms/step - loss: 1.1766
# Epoch 50/100
# 1033/1033 [==============================] - 3s 3ms/step - loss: 1.1697
# Epoch 51/100
# 1033/1033 [==============================] - 3s 3ms/step - loss: 1.1633
# Epoch 52/100
# 1033/1033 [==============================] - 3s 3ms/step - loss: 1.1571
# Epoch 53/100
# 1033/1033 [==============================] - 3s 3ms/step - loss: 1.1512
# Epoch 54/100
# 1033/1033 [==============================] - 3s 3ms/step - loss: 1.1456
# Epoch 55/100
# 1033/1033 [==============================] - 3s 3ms/step - loss: 1.1402
# Epoch 56/100
# 1033/1033 [==============================] - 3s 3ms/step - loss: 1.1350
# Epoch 57/100
# 1033/1033 [==============================] - 3s 3ms/step - loss: 1.1300
# Epoch 58/100
# 1033/1033 [==============================] - 3s 3ms/step - loss: 1.1253
# Epoch 59/100
# 1033/1033 [==============================] - 3s 3ms/step - loss: 1.1207
# Epoch 60/100
# 1033/1033 [==============================] - 3s 3ms/step - loss: 1.1163
# Epoch 61/100
# 1033/1033 [==============================] - 3s 3ms/step - loss: 1.1121
# Epoch 62/100
# 1033/1033 [==============================] - 3s 3ms/step - loss: 1.1080
# Epoch 63/100
# 1033/1033 [==============================] - 3s 3ms/step - loss: 1.1040
# Epoch 64/100
# 1033/1033 [==============================] - 3s 3ms/step - loss: 1.1002
# Epoch 65/100
# 1033/1033 [==============================] - 3s 3ms/step - loss: 1.0965
# Epoch 66/100
# 1033/1033 [==============================] - 3s 3ms/step - loss: 1.0929
# Epoch 67/100
# 1033/1033 [==============================] - 3s 3ms/step - loss: 1.0895
# Epoch 68/100
# 1033/1033 [==============================] - 3s 3ms/step - loss: 1.0861
# Epoch 69/100
# 1033/1033 [==============================] - 3s 3ms/step - loss: 1.0828
# Epoch 70/100
# 1033/1033 [==============================] - 3s 3ms/step - loss: 1.0797
# Epoch 71/100
# 1033/1033 [==============================] - 3s 3ms/step - loss: 1.0766
# Epoch 72/100
# 1033/1033 [==============================] - 3s 3ms/step - loss: 1.0736
# Epoch 73/100
# 1033/1033 [==============================] - 3s 3ms/step - loss: 1.0707
# Epoch 74/100
# 1033/1033 [==============================] - 3s 3ms/step - loss: 1.0679
# Epoch 75/100
# 1033/1033 [==============================] - 3s 3ms/step - loss: 1.0651
# Epoch 76/100
# 1033/1033 [==============================] - 3s 3ms/step - loss: 1.0624
# Epoch 77/100
# 1033/1033 [==============================] - 3s 3ms/step - loss: 1.0597
# Epoch 78/100
# 1033/1033 [==============================] - 3s 3ms/step - loss: 1.0572
# Epoch 79/100
# 1033/1033 [==============================] - 3s 3ms/step - loss: 1.0547
# Epoch 80/100
# 1033/1033 [==============================] - 3s 3ms/step - loss: 1.0522
# Epoch 81/100
# 1033/1033 [==============================] - 3s 3ms/step - loss: 1.0498
# Epoch 82/100
# 1033/1033 [==============================] - 3s 3ms/step - loss: 1.0475
# Epoch 83/100
# 1033/1033 [==============================] - 4s 4ms/step - loss: 1.0452
# Epoch 84/100
# 1033/1033 [==============================] - 4s 3ms/step - loss: 1.0430
# Epoch 85/100
# 1033/1033 [==============================] - 4s 3ms/step - loss: 1.0407
# Epoch 86/100
# 1033/1033 [==============================] - 4s 4ms/step - loss: 1.0386
# Epoch 87/100
# 1033/1033 [==============================] - 4s 3ms/step - loss: 1.0365
# Epoch 88/100
# 1033/1033 [==============================] - 4s 3ms/step - loss: 1.0344
# Epoch 89/100
# 1033/1033 [==============================] - 4s 3ms/step - loss: 1.0324
# Epoch 90/100
# 1033/1033 [==============================] - 3s 3ms/step - loss: 1.0304
# Epoch 91/100
# 1033/1033 [==============================] - 3s 3ms/step - loss: 1.0285
# Epoch 92/100
# 1033/1033 [==============================] - 3s 3ms/step - loss: 1.0265
# Epoch 93/100
# 1033/1033 [==============================] - 3s 3ms/step - loss: 1.0247
# Epoch 94/100
# 1033/1033 [==============================] - 3s 3ms/step - loss: 1.0228
# Epoch 95/100
# 1033/1033 [==============================] - 3s 3ms/step - loss: 1.0210
# Epoch 96/100
# 1033/1033 [==============================] - 3s 3ms/step - loss: 1.0192
# Epoch 97/100
# 1033/1033 [==============================] - 3s 3ms/step - loss: 1.0175
# Epoch 98/100
# 1033/1033 [==============================] - 4s 4ms/step - loss: 1.0157
# Epoch 99/100
# 1033/1033 [==============================] - 3s 3ms/step - loss: 1.0140
# Epoch 100/100
# 1033/1033 [==============================] - 3s 3ms/step - loss: 1.0123

# %%
#LSTM Prediction
y_pred= lstm.predict(X_test)

# %%
#Predicted vs True Adj Close Value – LSTM
plt.plot(y_test, label='True Value')
plt.plot(y_pred, label='LSTM Value')
plt.title('Prediction by LSTM')
plt.xlabel('Time Scale')
plt.ylabel('Scaled USD')
plt.legend()
plt.show()
